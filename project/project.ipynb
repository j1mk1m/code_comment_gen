# %%
import pandas as pd
import torch
import tqdm
from tqdm.auto import tqdm
tqdm.pandas()
from collections import Counter
import numpy as np

# %%
from datasets import load_dataset
dataset = load_dataset("code_search_net", "python")
df_train = dataset['train'].to_pandas().reset_index(drop = True)
df_val = dataset['validation'].to_pandas().reset_index(drop = True)
df_test = dataset['test'].to_pandas().reset_index(drop = True)
# Out:
# /Users/runqian0120/opt/anaconda3/lib/python3.9/site-packages/datasets/load.py:1461: FutureWarning: The repository for code_search_net contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/code_search_net
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(

# %% [markdown]
# ## Dataset Sizes

# %%
df_train['func_code_len'] = df_train['func_code_tokens'].progress_apply(lambda x : len(x))
df_val['func_code_len'] = df_val['func_code_tokens'].progress_apply(lambda x : len(x))
df_test['func_code_len'] = df_test['func_code_tokens'].progress_apply(lambda x : len(x))

df_train = df_train[df_train['func_code_len'] <= 500]
df_val = df_val[df_val['func_code_len'] <= 500]
df_test = df_test[df_test['func_code_len'] <= 500]
# Out:
#   0%|          | 0/412178 [00:00<?, ?it/s]
#   0%|          | 0/23107 [00:00<?, ?it/s]
#   0%|          | 0/22176 [00:00<?, ?it/s]

# %%
print(f"Train Size: {df_train.shape}")
print(f"Validation Size: {df_val.shape}")
print(f"Test Size: {df_test.shape}")
# Out:
# Train Size: (402906, 12)
# Validation Size: (22478, 12)
# Test Size: (21736, 12)

# %%
df_train.head()
# Out:
#   repository_name  func_path_in_repository                    func_name  \
# 0  proycon/pynlpl  pynlpl/formats/folia.py  AbstractElement.addidsuffix
# 1  proycon/pynlpl  pynlpl/formats/folia.py   AbstractElement.setparents
# 2  proycon/pynlpl  pynlpl/formats/folia.py       AbstractElement.setdoc
# 3  proycon/pynlpl  pynlpl/formats/folia.py      AbstractElement.hastext
# 4  proycon/pynlpl  pynlpl/formats/folia.py      AbstractElement.hasphon
#
#                                    whole_func_string language  \
# 0  def addidsuffix(self, idsuffix, recursive = Tr...   python
# 1  def setparents(self):\n        """Correct all ...   python
# 2  def setdoc(self,newdoc):\n        """Set a dif...   python
# 3  def hastext(self,cls='current',strict=True, co...   python
# 4  def hasphon(self,cls='current',strict=True,cor...   python
#
#                                     func_code_string  \
# 0  def addidsuffix(self, idsuffix, recursive = Tr...
# 1  def setparents(self):\n        """Correct all ...
# 2  def setdoc(self,newdoc):\n        """Set a dif...
# 3  def hastext(self,cls='current',strict=True, co...
# 4  def hasphon(self,cls='current',strict=True,cor...
#
#                                     func_code_tokens  \
# 0  [def, addidsuffix, (, self, ,, idsuffix, ,, re...
# 1  [def, setparents, (, self, ), :, for, c, in, s...
# 2  [def, setdoc, (, self, ,, newdoc, ), :, self, ...
# 3  [def, hastext, (, self, ,, cls, =, 'current', ...
# 4  [def, hasphon, (, self, ,, cls, =, 'current', ...
#
#                            func_documentation_string  \
# 0  Appends a suffix to this element's ID, and opt...
# 1  Correct all parent relations for elements with...
# 2  Set a different document. Usually no need to c...
# 3  Does this element have text (of the specified ...
# 4  Does this element have phonetic content (of th...
#
#                            func_documentation_tokens split_name  \
# 0  [Appends, a, suffix, to, this, element, s, ID,...      train
# 1  [Correct, all, parent, relations, for, element...      train
# 2  [Set, a, different, document, ., Usually, no, ...      train
# 3  [Does, this, element, have, text, (, of, the, ...      train
# 4  [Does, this, element, have, phonetic, content,...      train
#
#                                        func_code_url  func_code_len
# 0  https://github.com/proycon/pynlpl/blob/7707f69...             44
# 1  https://github.com/proycon/pynlpl/blob/7707f69...             29
# 2  https://github.com/proycon/pynlpl/blob/7707f69...             53
# 3  https://github.com/proycon/pynlpl/blob/7707f69...            106
# 4  https://github.com/proycon/pynlpl/blob/7707f69...            103

# %%
df_test.head()
# Out:
#    repository_name                func_path_in_repository  \
# 0  soimort/you-get      src/you_get/extractors/youtube.py
# 1  soimort/you-get       src/you_get/extractors/miomio.py
# 2  soimort/you-get     src/you_get/extractors/fc2video.py
# 3  soimort/you-get     src/you_get/extractors/fc2video.py
# 4  soimort/you-get  src/you_get/extractors/dailymotion.py
#
#                   func_name  \
# 0  YouTube.get_vid_from_url
# 1      sina_xml_to_url_list
# 2                  makeMimi
# 3         fc2video_download
# 4      dailymotion_download
#
#                                    whole_func_string language  \
# 0  def get_vid_from_url(url):\n        """Extract...   python
# 1  def sina_xml_to_url_list(xml_data):\n    """st...   python
# 2  def makeMimi(upid):\n    """From http://cdn37....   python
# 3  def fc2video_download(url, output_dir = '.', m...   python
# 4  def dailymotion_download(url, output_dir='.', ...   python
#
#                                     func_code_string  \
# 0  def get_vid_from_url(url):\n        """Extract...
# 1  def sina_xml_to_url_list(xml_data):\n    """st...
# 2  def makeMimi(upid):\n    """From http://cdn37....
# 3  def fc2video_download(url, output_dir = '.', m...
# 4  def dailymotion_download(url, output_dir='.', ...
#
#                                     func_code_tokens  \
# 0  [def, get_vid_from_url, (, url, ), :, return, ...
# 1  [def, sina_xml_to_url_list, (, xml_data, ), :,...
# 2  [def, makeMimi, (, upid, ), :, strSeed, =, "gG...
# 3  [def, fc2video_download, (, url, ,, output_dir...
# 4  [def, dailymotion_download, (, url, ,, output_...
#
#                            func_documentation_string  \
# 0                        Extracts video ID from URL.
# 1  str->list\n    Convert XML to URL List.\n    F...
# 2  From http://cdn37.atwikiimg.com/sitescript/pub...
# 3                                            wrapper
# 4               Downloads Dailymotion videos by URL.
#
#                            func_documentation_tokens split_name  \
# 0                [Extracts, video, ID, from, URL, .]       test
# 1  [str, -, >, list, Convert, XML, to, URL, List,...       test
# 2  [From, http, :, //, cdn37, ., atwikiimg, ., co...       test
# 3                                          [wrapper]       test
# 4       [Downloads, Dailymotion, videos, by, URL, .]       test
#
#                                        func_code_url  func_code_len
# 0  https://github.com/soimort/you-get/blob/b746ac...             53
# 1  https://github.com/soimort/you-get/blob/b746ac...             52
# 2  https://github.com/soimort/you-get/blob/b746ac...             30
# 3  https://github.com/soimort/you-get/blob/b746ac...             66
# 4  https://github.com/soimort/you-get/blob/b746ac...            150

# %%
df_val.head()
# Out:
#     repository_name     func_path_in_repository            func_name  \
# 1  openai/baselines    baselines/deepq/deepq.py  ActWrapper.save_act
# 2  openai/baselines  baselines/common/models.py           nature_cnn
# 3  openai/baselines  baselines/common/models.py                  mlp
# 4  openai/baselines  baselines/common/models.py                 lstm
# 5  openai/baselines  baselines/common/models.py            conv_only
#
#                                    whole_func_string language  \
# 1  def save_act(self, path=None):\n        """Sav...   python
# 2  def nature_cnn(unscaled_images, **conv_kwargs)...   python
# 3  def mlp(num_layers=2, num_hidden=64, activatio...   python
# 4  def lstm(nlstm=128, layer_norm=False):\n    ""...   python
# 5  def conv_only(convs=[(32, 8, 4), (64, 4, 2), (...   python
#
#                                     func_code_string  \
# 1  def save_act(self, path=None):\n        """Sav...
# 2  def nature_cnn(unscaled_images, **conv_kwargs)...
# 3  def mlp(num_layers=2, num_hidden=64, activatio...
# 4  def lstm(nlstm=128, layer_norm=False):\n    ""...
# 5  def conv_only(convs=[(32, 8, 4), (64, 4, 2), (...
#
#                                     func_code_tokens  \
# 1  [def, save_act, (, self, ,, path, =, None, ), ...
# 2  [def, nature_cnn, (, unscaled_images, ,, *, *,...
# 3  [def, mlp, (, num_layers, =, 2, ,, num_hidden,...
# 4  [def, lstm, (, nlstm, =, 128, ,, layer_norm, =...
# 5  [def, conv_only, (, convs, =, [, (, 32, ,, 8, ...
#
#                            func_documentation_string  \
# 1           Save model to a pickle located at `path`
# 2                             CNN from Nature paper.
# 3  Stack of fully-connected layers to be used in ...
# 4  Builds LSTM (Long-Short Term Memory) network t...
# 5  convolutions-only net\n\n    Parameters:\n    ...
#
#                            func_documentation_tokens split_name  \
# 1    [Save, model, to, a, pickle, located, at, path]      valid
# 2                      [CNN, from, Nature, paper, .]      valid
# 3  [Stack, of, fully, -, connected, layers, to, b...      valid
# 4  [Builds, LSTM, (, Long, -, Short, Term, Memory...      valid
# 5                       [convolutions, -, only, net]      valid
#
#                                        func_code_url  func_code_len
# 1  https://github.com/openai/baselines/blob/33010...            171
# 2  https://github.com/openai/baselines/blob/33010...            168
# 3  https://github.com/openai/baselines/blob/33010...            105
# 4  https://github.com/openai/baselines/blob/33010...            194
# 5  https://github.com/openai/baselines/blob/33010...            109

# %% [markdown]
# ## Getting AST of functions

# %%
df_train = df_train.head(100000)
df_val = df_val.head(5000)
df_test = df_test.head(5000)

# %%
import ast

# %% [markdown]
# ## Filter out AST Errors (caused by comments in foreign languages)

# %%
def get_ast(code_str):
    try:
        return ast.dump(ast.parse(code_str), indent=2)
    except SyntaxError as e:
        return ''
    
df_train['ast'] = df_train['func_code_string'].progress_apply(get_ast)
df_val['ast'] = df_val['func_code_string'].progress_apply(get_ast)
df_test['ast'] = df_test['func_code_string'].progress_apply(get_ast)

df_train = df_train[df_train['ast'] != '']#.iloc[0]['whole_func_string']
df_val = df_val[df_val['ast'] != '']
df_test = df_test[df_test['ast'] != '']
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]
#   0%|          | 0/5000 [00:00<?, ?it/s]

# %%
def get_tokenized_ast(code_str):
    def tokenize_ast(node):
        tokens = []
        for child in ast.iter_child_nodes(node):
            # Tokenize the node type
            tokens.append(type(child).__name__)
            # Recursively tokenize children
            tokens.extend(tokenize_ast(child))
        return tokens

    # Tokenize the AST starting from the root
    root = ast.parse(code_str)
    return tokenize_ast(root)

df_train['ast_tokens'] = df_train['func_code_string'].progress_apply(get_tokenized_ast)
df_val['ast_tokens'] = df_val['func_code_string'].progress_apply(get_tokenized_ast)
df_test['ast_tokens'] = df_test['func_code_string'].progress_apply(get_tokenized_ast)
# Out:
#   0%|          | 0/98803 [00:00<?, ?it/s]
#   0%|          | 0/4880 [00:00<?, ?it/s]
#   0%|          | 0/4983 [00:00<?, ?it/s]

# %%
print(df_train.shape)
print(df_val.shape)
print(df_test.shape)
# Out:
# (98803, 14)
# (4880, 14)
# (4983, 14)

# %% [markdown]
# ## Adding Doc Strings

# %% [markdown]
# #### Enrich with helpful information for docstring

# %%
def add_params(df):
    def calc_num_params(tokens) :
        try:
            close_idx = np.where(tokens ==')')[0][0]
            open_idx = np.where(tokens=='(')[0][0]
            segment = tokens[open_idx + 1:close_idx]  # Slice the array to get the segment between '(' and ')'
            commas = np.count_nonzero(segment == ',')
            return commas+1
        except:
            # print(tokens)
            return -1

    df['fn_name'] = df['func_name'].apply(lambda x: x.split('.')[-1])
    df['class_fn'] = df['func_name'].apply(lambda x: '.' in x)
    df['num_params'] = df['func_code_tokens'].apply(calc_num_params)
    return df

df_train = add_params(df_train)
df_val = add_params(df_val)
df_test = add_params(df_test)

# %%
def calc_doc_string(df):
    dfs = []

    def check_if_function_used(tokens, fn_name):
        m1 = tokens[:-1] == fn_name
        m2 = tokens[1:] == '('
        combined_mask = m1 & m2

        indices = np.where(combined_mask)[0]
        if indices.size == 0:
            return -1
        return indices[0]

    all_repos = set(df['repository_name'])
    # print(df)
    # print(all_repos)

    for repo_name in tqdm(all_repos):
        filtered = df[df['repository_name'] == repo_name]
        filtered['used_function_docstring'] = filtered.apply(lambda row: {}, axis=1)

        # Get documentation string
        all_fns = set(filtered['fn_name'])
        for fn in all_fns:
            for i, row in filtered.iterrows():
                if row['fn_name'] == fn:
                    continue
                # print(fn)
                # print(row)
                try:
                    fn_body = row['func_code_tokens'][np.where(row['func_code_tokens'] == ':')[0][0]+1:]
                except:
                    continue
                
                index = check_if_function_used(fn_body, fn)

                if index != -1: 
                    # Check num params
                    if fn_body[index-1] == '.': 
                        # function called a class method
                        doc_string = filtered[(filtered['fn_name'] == fn) & (filtered['class_fn'])].reset_index(drop=True)
                        try:
                            filtered.loc[i, 'used_function_docstring'][fn] = doc_string.iloc[0]['func_documentation_tokens']
                        except:
                            pass
                    else :
                        # function called a non-class method
                        doc_string = filtered[(filtered['fn_name'] == fn) & (filtered['class_fn'] == False)].reset_index(drop=True)
                        try:
                            filtered.loc[i, 'used_function_docstring'][fn] = doc_string.iloc[0]['func_documentation_tokens']
                        except:
                            pass
        dfs.append(filtered)
    return pd.concat(dfs).reset_index(drop=True)

df_train = calc_doc_string(df_train)
df_val = calc_doc_string(df_val)
df_test = calc_doc_string(df_test)
# Out:
#   0%|          | 0/4054 [00:00<?, ?it/s]
# /var/folders/2t/31twf06s5gq20q0f2m2h2zlh0000gn/T/ipykernel_92776/4234615731.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered['used_function_docstring'] = filtered.apply(lambda row: {}, axis=1)
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/36 [00:00<?, ?it/s]

# %%
df_train.head(10)
# Out:
#                    repository_name func_path_in_repository  \
# 0  DirectlineDev/python-myeventhub    myeventhub/client.py
# 1  DirectlineDev/python-myeventhub    myeventhub/client.py
# 2  DirectlineDev/python-myeventhub    myeventhub/client.py
# 3  DirectlineDev/python-myeventhub    myeventhub/client.py
# 4               tommyod/streprogen   streprogen/program.py
# 5               tommyod/streprogen   streprogen/program.py
# 6               tommyod/streprogen   streprogen/program.py
# 7               tommyod/streprogen   streprogen/program.py
# 8               tommyod/streprogen   streprogen/program.py
# 9               tommyod/streprogen   streprogen/program.py
#
#                                func_name  \
# 0                           Client._call
# 1                 Client.get_action_list
# 2                Client.get_action_by_id
# 3                     Client.all_actions
# 4                   Program._set_scalers
# 5                      Program._validate
# 6                       Program.add_days
# 7              Program.repstring_penalty
# 8                Program._render_dynamic
# 9  Program._initialize_render_dictionary
#
#                                    whole_func_string language  \
# 0  def _call(self, method, **kwargs):\n        ""...   python
# 1  def get_action_list(self, page=1):\n        ""...   python
# 2  def get_action_by_id(self, action_id):\n      ...   python
# 3  def all_actions(self):\n        """ Генератор,...   python
# 4  def _set_scalers(self):\n        """\n        ...   python
# 5  def _validate(self):\n        """\n        The...   python
# 6  def add_days(self, *days):\n        """Add one...   python
# 7  def repstring_penalty(reps, intensities, desir...   python
# 8  def _render_dynamic(self, dynamic_exercise, mi...   python
# 9  def _initialize_render_dictionary(self):\n    ...   python
#
#                                     func_code_string  \
# 0  def _call(self, method, **kwargs):\n        ""...
# 1  def get_action_list(self, page=1):\n        ""...
# 2  def get_action_by_id(self, action_id):\n      ...
# 3  def all_actions(self):\n        """ Генератор,...
# 4  def _set_scalers(self):\n        """\n        ...
# 5  def _validate(self):\n        """\n        The...
# 6  def add_days(self, *days):\n        """Add one...
# 7  def repstring_penalty(reps, intensities, desir...
# 8  def _render_dynamic(self, dynamic_exercise, mi...
# 9  def _initialize_render_dictionary(self):\n    ...
#
#                                     func_code_tokens  \
# 0  [def, _call, (, self, ,, method, ,, *, *, kwar...
# 1  [def, get_action_list, (, self, ,, page, =, 1,...
# 2  [def, get_action_by_id, (, self, ,, action_id,...
# 3  [def, all_actions, (, self, ), :, count, =, se...
# 4  [def, _set_scalers, (, self, ), :, # Set defau...
# 5  [def, _validate, (, self, ), :, # Validate the...
# 6  [def, add_days, (, self, ,, *, days, ), :, for...
# 7  [def, repstring_penalty, (, reps, ,, intensiti...
# 8  [def, _render_dynamic, (, self, ,, dynamic_exe...
# 9  [def, _initialize_render_dictionary, (, self, ...
#
#                            func_documentation_string  \
# 0                                   Вызов метода API
# 1  Получение списка событий\n        :param page:...
# 2              Получение детального описания события
# 3                Генератор, возвращающий все события
# 4  Set the variables self._scalers as given by se...
# 5  The purpose of this method is to verify that t...
# 6  Add one or several days to the program.\n    \...
# 7  Penalty function which calculates how "bad" a ...
# 8  Render a single dynamic exercise.\n        Thi...
# 9  Initialize a dictionary for rendered values.\n...
#
#                            func_documentation_tokens split_name  \
# 0                               [Вызов, метода, API]      train
# 1  [Получение, списка, событий, :, param, page, :...      train
# 2         [Получение, детального, описания, события]      train
# 3            [Генератор, возвращающий, все, события]      train
# 4  [Set, the, variables, self, ., _scalers, as, g...      train
# 5  [The, purpose, of, this, method, is, to, verif...      train
# 6  [Add, one, or, several, days, to, the, program...      train
# 7  [Penalty, function, which, calculates, how, ba...      train
# 8  [Render, a, single, dynamic, exercise, ., This...      train
# 9  [Initialize, a, dictionary, for, rendered, val...      train
#
#                                        func_code_url  \
# 0  https://github.com/DirectlineDev/python-myeven...
# 1  https://github.com/DirectlineDev/python-myeven...
# 2  https://github.com/DirectlineDev/python-myeven...
# 3  https://github.com/DirectlineDev/python-myeven...
# 4  https://github.com/tommyod/streprogen/blob/21b...
# 5  https://github.com/tommyod/streprogen/blob/21b...
# 6  https://github.com/tommyod/streprogen/blob/21b...
# 7  https://github.com/tommyod/streprogen/blob/21b...
# 8  https://github.com/tommyod/streprogen/blob/21b...
# 9  https://github.com/tommyod/streprogen/blob/21b...
#
#                                                  ast  \
# 0  Module(\n  body=[\n    FunctionDef(\n      nam...
# 1  Module(\n  body=[\n    FunctionDef(\n      nam...
# 2  Module(\n  body=[\n    FunctionDef(\n      nam...
# 3  Module(\n  body=[\n    FunctionDef(\n      nam...
# 4  Module(\n  body=[\n    FunctionDef(\n      nam...
# 5  Module(\n  body=[\n    FunctionDef(\n      nam...
# 6  Module(\n  body=[\n    FunctionDef(\n      nam...
# 7  Module(\n  body=[\n    FunctionDef(\n      nam...
# 8  Module(\n  body=[\n    FunctionDef(\n      nam...
# 9  Module(\n  body=[\n    FunctionDef(\n      nam...
#
#                          fn_name  class_fn  num_params  \
# 0                          _call      True           3
# 1                get_action_list      True           2
# 2               get_action_by_id      True           2
# 3                    all_actions      True           1
# 4                   _set_scalers      True           1
# 5                      _validate      True           1
# 6                       add_days      True           2
# 7              repstring_penalty      True           5
# 8                _render_dynamic      True           6
# 9  _initialize_render_dictionary      True           1
#
#                              used_function_docstring  \
# 0                                                 {}
# 1              {'_call': ['Вызов', 'метода', 'API']}
# 2              {'_call': ['Вызов', 'метода', 'API']}
# 3  {'get_action_list': ['Получение', 'списка', 'с...
# 4                                                 {}
# 5  {'weekly_growth': ['Calculate', 'the', 'weekly...
# 6                                                 {}
# 7  {'spread': ['Returns', 'the', 'maximal', 'spre...
# 8  {'repstring_penalty': ['Penalty', 'function', ...
# 9                                                 {}
#
#                                           ast_tokens
# 0  [FunctionDef, arguments, arg, arg, arg, Expr, ...
# 1  [FunctionDef, arguments, arg, arg, Constant, E...
# 2  [FunctionDef, arguments, arg, arg, Expr, Const...
# 3  [FunctionDef, arguments, arg, Expr, Constant, ...
# 4  [FunctionDef, arguments, arg, Expr, Constant, ...
# 5  [FunctionDef, arguments, arg, Expr, Constant, ...
# 6  [FunctionDef, arguments, arg, arg, Expr, Const...
# 7  [FunctionDef, arguments, arg, arg, arg, arg, a...
# 8  [FunctionDef, arguments, arg, arg, arg, arg, a...
# 9  [FunctionDef, arguments, arg, Expr, Constant, ...

# %%
df_val.head(10)
# Out:
#   repository_name     func_path_in_repository  \
# 0    aleju/imgaug  imgaug/augmentables/kps.py
# 1    aleju/imgaug  imgaug/augmentables/kps.py
# 2    aleju/imgaug  imgaug/augmentables/kps.py
# 3    aleju/imgaug  imgaug/augmentables/kps.py
# 4    aleju/imgaug  imgaug/augmentables/kps.py
# 5    aleju/imgaug  imgaug/augmentables/kps.py
# 6    aleju/imgaug  imgaug/augmentables/kps.py
# 7    aleju/imgaug  imgaug/augmentables/kps.py
# 8    aleju/imgaug  imgaug/augmentables/kps.py
# 9    aleju/imgaug  imgaug/augmentables/kps.py
#
#                                     func_name  \
# 0                    compute_geometric_median
# 1                            Keypoint.project
# 2                              Keypoint.shift
# 3                      Keypoint.draw_on_image
# 4  Keypoint.generate_similar_points_manhattan
# 5                               Keypoint.copy
# 6                           Keypoint.deepcopy
# 7                         KeypointsOnImage.on
# 8              KeypointsOnImage.draw_on_image
# 9                      KeypointsOnImage.shift
#
#                                    whole_func_string language  \
# 0  def compute_geometric_median(X, eps=1e-5):\n  ...   python
# 1  def project(self, from_shape, to_shape):\n    ...   python
# 2  def shift(self, x=0, y=0):\n        """\n     ...   python
# 3  def draw_on_image(self, image, color=(0, 255, ...   python
# 4  def generate_similar_points_manhattan(self, nb...   python
# 5  def copy(self, x=None, y=None):\n        """\n...   python
# 6  def deepcopy(self, x=None, y=None):\n        "...   python
# 7  def on(self, image):\n        """\n        Pro...   python
# 8  def draw_on_image(self, image, color=(0, 255, ...   python
# 9  def shift(self, x=0, y=0):\n        """\n     ...   python
#
#                                     func_code_string  \
# 0  def compute_geometric_median(X, eps=1e-5):\n  ...
# 1  def project(self, from_shape, to_shape):\n    ...
# 2  def shift(self, x=0, y=0):\n        """\n     ...
# 3  def draw_on_image(self, image, color=(0, 255, ...
# 4  def generate_similar_points_manhattan(self, nb...
# 5  def copy(self, x=None, y=None):\n        """\n...
# 6  def deepcopy(self, x=None, y=None):\n        "...
# 7  def on(self, image):\n        """\n        Pro...
# 8  def draw_on_image(self, image, color=(0, 255, ...
# 9  def shift(self, x=0, y=0):\n        """\n     ...
#
#                                     func_code_tokens  \
# 0  [def, compute_geometric_median, (, X, ,, eps, ...
# 1  [def, project, (, self, ,, from_shape, ,, to_s...
# 2  [def, shift, (, self, ,, x, =, 0, ,, y, =, 0, ...
# 3  [def, draw_on_image, (, self, ,, image, ,, col...
# 4  [def, generate_similar_points_manhattan, (, se...
# 5  [def, copy, (, self, ,, x, =, None, ,, y, =, N...
# 6  [def, deepcopy, (, self, ,, x, =, None, ,, y, ...
# 7  [def, on, (, self, ,, image, ), :, shape, =, n...
# 8  [def, draw_on_image, (, self, ,, image, ,, col...
# 9  [def, shift, (, self, ,, x, =, 0, ,, y, =, 0, ...
#
#                            func_documentation_string  \
# 0  Estimate the geometric median of points in 2D....
# 1  Project the keypoint onto a new position on a ...
# 2  Move the keypoint around on an image.\n\n     ...
# 3  Draw the keypoint onto a given image.\n\n     ...
# 4  Generate nearby points to this keypoint based ...
# 5  Create a shallow copy of the Keypoint object.\...
# 6  Create a deep copy of the Keypoint object.\n\n...
# 7  Project keypoints from one image to a new one....
# 8  Draw all keypoints onto a given image.\n\n    ...
# 9  Move the keypoints around on an image.\n\n    ...
#
#                            func_documentation_tokens split_name  \
# 0  [Estimate, the, geometric, median, of, points,...      valid
# 1  [Project, the, keypoint, onto, a, new, positio...      valid
# 2    [Move, the, keypoint, around, on, an, image, .]      valid
# 3    [Draw, the, keypoint, onto, a, given, image, .]      valid
# 4  [Generate, nearby, points, to, this, keypoint,...      valid
# 5  [Create, a, shallow, copy, of, the, Keypoint, ...      valid
# 6  [Create, a, deep, copy, of, the, Keypoint, obj...      valid
# 7  [Project, keypoints, from, one, image, to, a, ...      valid
# 8   [Draw, all, keypoints, onto, a, given, image, .]      valid
# 9   [Move, the, keypoints, around, on, an, image, .]      valid
#
#                                        func_code_url  \
# 0  https://github.com/aleju/imgaug/blob/786be74aa...
# 1  https://github.com/aleju/imgaug/blob/786be74aa...
# 2  https://github.com/aleju/imgaug/blob/786be74aa...
# 3  https://github.com/aleju/imgaug/blob/786be74aa...
# 4  https://github.com/aleju/imgaug/blob/786be74aa...
# 5  https://github.com/aleju/imgaug/blob/786be74aa...
# 6  https://github.com/aleju/imgaug/blob/786be74aa...
# 7  https://github.com/aleju/imgaug/blob/786be74aa...
# 8  https://github.com/aleju/imgaug/blob/786be74aa...
# 9  https://github.com/aleju/imgaug/blob/786be74aa...
#
#                                                  ast  \
# 0  Module(\n  body=[\n    FunctionDef(\n      nam...
# 1  Module(\n  body=[\n    FunctionDef(\n      nam...
# 2  Module(\n  body=[\n    FunctionDef(\n      nam...
# 3  Module(\n  body=[\n    FunctionDef(\n      nam...
# 4  Module(\n  body=[\n    FunctionDef(\n      nam...
# 5  Module(\n  body=[\n    FunctionDef(\n      nam...
# 6  Module(\n  body=[\n    FunctionDef(\n      nam...
# 7  Module(\n  body=[\n    FunctionDef(\n      nam...
# 8  Module(\n  body=[\n    FunctionDef(\n      nam...
# 9  Module(\n  body=[\n    FunctionDef(\n      nam...
#
#                              fn_name  class_fn  num_params  \
# 0           compute_geometric_median     False           2
# 1                            project      True           3
# 2                              shift      True           3
# 3                      draw_on_image      True           5
# 4  generate_similar_points_manhattan      True           4
# 5                               copy      True           3
# 6                           deepcopy      True           3
# 7                                 on      True           2
# 8                      draw_on_image      True           5
# 9                              shift      True           3
#
#                              used_function_docstring  \
# 0                                                 {}
# 1  {'project_coords': ['Project', 'coordinates', ...
# 2  {'deepcopy': ['Create', 'a', 'deep', 'copy', '...
# 3  {'copy': ['Create', 'a', 'shallow', 'copy', 'o...
# 4  {'deepcopy': ['Create', 'a', 'deep', 'copy', '...
# 5  {'deepcopy': ['Create', 'a', 'deep', 'copy', '...
# 6                                                 {}
# 7  {'normalize_shape': ['Normalize', 'a', 'shape'...
# 8  {'copy': ['Create', 'a', 'shallow', 'copy', 'o...
# 9  {'deepcopy': ['Create', 'a', 'deep', 'copy', '...
#
#                                           ast_tokens
# 0  [FunctionDef, arguments, arg, arg, Constant, E...
# 1  [FunctionDef, arguments, arg, arg, arg, Expr, ...
# 2  [FunctionDef, arguments, arg, arg, arg, Consta...
# 3  [FunctionDef, arguments, arg, arg, arg, arg, a...
# 4  [FunctionDef, arguments, arg, arg, arg, arg, C...
# 5  [FunctionDef, arguments, arg, arg, arg, Consta...
# 6  [FunctionDef, arguments, arg, arg, arg, Consta...
# 7  [FunctionDef, arguments, arg, arg, Expr, Const...
# 8  [FunctionDef, arguments, arg, arg, arg, arg, a...
# 9  [FunctionDef, arguments, arg, arg, arg, Consta...

# %%
df_test.head(10)
# Out:
#       repository_name               func_path_in_repository  \
# 0  python/performance                performance/compare.py
# 1  python/performance                performance/compare.py
# 2  python/performance                performance/compare.py
# 3  python/performance                performance/compare.py
# 4  python/performance      performance/benchmarks/bm_mdp.py
# 5  python/performance  performance/benchmarks/bm_nqueens.py
# 6  python/performance  performance/benchmarks/bm_nqueens.py
# 7  python/performance       performance/benchmarks/bm_go.py
# 8  python/performance       performance/benchmarks/bm_go.py
# 9  python/performance       performance/benchmarks/bm_go.py
#
#                 func_name                                  whole_func_string  \
# 0       tdist95conf_level  def tdist95conf_level(df):\n    """Approximate...
# 1  pooled_sample_variance  def pooled_sample_variance(sample1, sample2):\...
# 2                  tscore  def tscore(sample1, sample2):\n    """Calculat...
# 3          is_significant  def is_significant(sample1, sample2):\n    """...
# 4                topoSort  def topoSort(roots, getParents):\n    """Retur...
# 5            permutations  def permutations(iterable, r=None):\n    """pe...
# 6                n_queens  def n_queens(queen_count):\n    """N-Queens so...
# 7            UCTNode.play  def play(self, board):\n        """ uct tree s...
# 8          UCTNode.select  def select(self, board):\n        """ select m...
# 9  UCTNode.random_playout  def random_playout(self, board):\n        """ ...
#
#   language                                   func_code_string  \
# 0   python  def tdist95conf_level(df):\n    """Approximate...
# 1   python  def pooled_sample_variance(sample1, sample2):\...
# 2   python  def tscore(sample1, sample2):\n    """Calculat...
# 3   python  def is_significant(sample1, sample2):\n    """...
# 4   python  def topoSort(roots, getParents):\n    """Retur...
# 5   python  def permutations(iterable, r=None):\n    """pe...
# 6   python  def n_queens(queen_count):\n    """N-Queens so...
# 7   python  def play(self, board):\n        """ uct tree s...
# 8   python  def select(self, board):\n        """ select m...
# 9   python  def random_playout(self, board):\n        """ ...
#
#                                     func_code_tokens  \
# 0  [def, tdist95conf_level, (, df, ), :, df, =, i...
# 1  [def, pooled_sample_variance, (, sample1, ,, s...
# 2  [def, tscore, (, sample1, ,, sample2, ), :, if...
# 3  [def, is_significant, (, sample1, ,, sample2, ...
# 4  [def, topoSort, (, roots, ,, getParents, ), :,...
# 5  [def, permutations, (, iterable, ,, r, =, None...
# 6  [def, n_queens, (, queen_count, ), :, cols, =,...
# 7  [def, play, (, self, ,, board, ), :, color, =,...
# 8  [def, select, (, self, ,, board, ), :, if, sel...
# 9  [def, random_playout, (, self, ,, board, ), :,...
#
#                            func_documentation_string  \
# 0  Approximate the 95% confidence interval for St...
# 1  Find the pooled sample variance for two sample...
# 2  Calculate a t-test score for the difference be...
# 3  Determine whether two samples differ significa...
# 4  Return a topological sorting of nodes in a gra...
# 5  permutations(range(3), 2) --> (0,1) (0,2) (1,0...
# 6  N-Queens solver.\n\n    Args:\n        queen_c...
# 7                                    uct tree search
# 8  select move; unexplored children first, then a...
# 9                random play until both players pass
#
#                            func_documentation_tokens split_name  \
# 0  [Approximate, the, 95%, confidence, interval, ...       test
# 1  [Find, the, pooled, sample, variance, for, two...       test
# 2  [Calculate, a, t, -, test, score, for, the, di...       test
# 3  [Determine, whether, two, samples, differ, sig...       test
# 4  [Return, a, topological, sorting, of, nodes, i...       test
# 5  [permutations, (, range, (, 3, ), 2, ), --, >,...       test
# 6                          [N, -, Queens, solver, .]       test
# 7                                [uct, tree, search]       test
# 8  [select, move, ;, unexplored, children, first,...       test
# 9         [random, play, until, both, players, pass]       test
#
#                                        func_code_url  \
# 0  https://github.com/python/performance/blob/2a9...
# 1  https://github.com/python/performance/blob/2a9...
# 2  https://github.com/python/performance/blob/2a9...
# 3  https://github.com/python/performance/blob/2a9...
# 4  https://github.com/python/performance/blob/2a9...
# 5  https://github.com/python/performance/blob/2a9...
# 6  https://github.com/python/performance/blob/2a9...
# 7  https://github.com/python/performance/blob/2a9...
# 8  https://github.com/python/performance/blob/2a9...
# 9  https://github.com/python/performance/blob/2a9...
#
#                                                  ast                 fn_name  \
# 0  Module(\n  body=[\n    FunctionDef(\n      nam...       tdist95conf_level
# 1  Module(\n  body=[\n    FunctionDef(\n      nam...  pooled_sample_variance
# 2  Module(\n  body=[\n    FunctionDef(\n      nam...                  tscore
# 3  Module(\n  body=[\n    FunctionDef(\n      nam...          is_significant
# 4  Module(\n  body=[\n    FunctionDef(\n      nam...                topoSort
# 5  Module(\n  body=[\n    FunctionDef(\n      nam...            permutations
# 6  Module(\n  body=[\n    FunctionDef(\n      nam...                n_queens
# 7  Module(\n  body=[\n    FunctionDef(\n      nam...                    play
# 8  Module(\n  body=[\n    FunctionDef(\n      nam...                  select
# 9  Module(\n  body=[\n    FunctionDef(\n      nam...          random_playout
#
#    class_fn  num_params                            used_function_docstring  \
# 0     False           1                                                 {}
# 1     False           2                                                 {}
# 2     False           2  {'pooled_sample_variance': ['Find', 'the', 'po...
# 3     False           2  {'tdist95conf_level': ['Approximate', 'the', '...
# 4     False           2                                                 {}
# 5     False           2                                                 {}
# 6     False           1  {'permutations': ['permutations', '(', 'range'...
# 7      True           2  {'random_playout': ['random', 'play', 'until',...
# 8      True           2                                                 {}
# 9      True           2                                                 {}
#
#                                           ast_tokens
# 0  [FunctionDef, arguments, arg, Expr, Constant, ...
# 1  [FunctionDef, arguments, arg, arg, Expr, Const...
# 2  [FunctionDef, arguments, arg, arg, Expr, Const...
# 3  [FunctionDef, arguments, arg, arg, Expr, Const...
# 4  [FunctionDef, arguments, arg, arg, Expr, Const...
# 5  [FunctionDef, arguments, arg, arg, Constant, E...
# 6  [FunctionDef, arguments, arg, Expr, Constant, ...
# 7  [FunctionDef, arguments, arg, arg, Expr, Const...
# 8  [FunctionDef, arguments, arg, arg, Expr, Const...
# 9  [FunctionDef, arguments, arg, arg, Expr, Const...

# %% [markdown]
# ## Pickle Dataframes for later use

# %%
df_train.to_pickle("df_train.pkl")
df_val.to_pickle("df_val.pkl")
df_test.to_pickle("df_test.pkl")

# %% [markdown]
# ## Load Dataframes

# %%
df_train = pd.read_pickle("df_train.pkl")
df_val = pd.read_pickle("df_val.pkl")
df_test = pd.read_pickle("df_test.pkl")

# %%
df_train
# Out:
#          repository_name  func_path_in_repository  \
# 0         proycon/pynlpl  pynlpl/formats/folia.py
# 1         proycon/pynlpl  pynlpl/formats/folia.py
# 2         proycon/pynlpl  pynlpl/formats/folia.py
# 3         proycon/pynlpl  pynlpl/formats/folia.py
# 4         proycon/pynlpl  pynlpl/formats/folia.py
# ...                  ...                      ...
# 102284  pyokagan/pyglreg                 glreg.py
# 102285  pyokagan/pyglreg                 glreg.py
# 102286  pyokagan/pyglreg                 glreg.py
# 102287  pyokagan/pyglreg                 glreg.py
# 102288  pyokagan/pyglreg                 glreg.py
#
#                           func_name  \
# 0       AbstractElement.addidsuffix
# 1        AbstractElement.setparents
# 2            AbstractElement.setdoc
# 3           AbstractElement.hastext
# 4           AbstractElement.hasphon
# ...                             ...
# 102284                Registry.text
# 102285            Registry.get_type
# 102286        Registry.get_features
# 102287      Registry.get_extensions
# 102288        Registry.get_requires
#
#                                         whole_func_string language  \
# 0       def addidsuffix(self, idsuffix, recursive = Tr...   python
# 1       def setparents(self):\n        """Correct all ...   python
# 2       def setdoc(self,newdoc):\n        """Set a dif...   python
# 3       def hastext(self,cls='current',strict=True, co...   python
# 4       def hasphon(self,cls='current',strict=True,cor...   python
# ...                                                   ...      ...
# 102284  def text(self):\n        """Formatted API decl...   python
# 102285  def get_type(self, name, api=None):\n        "...   python
# 102286  def get_features(self, api=None):\n        """...   python
# 102287  def get_extensions(self, support=None):\n     ...   python
# 102288  def get_requires(self, api=None, profile=None,...   python
#
#                                          func_code_string  \
# 0       def addidsuffix(self, idsuffix, recursive = Tr...
# 1       def setparents(self):\n        """Correct all ...
# 2       def setdoc(self,newdoc):\n        """Set a dif...
# 3       def hastext(self,cls='current',strict=True, co...
# 4       def hasphon(self,cls='current',strict=True,cor...
# ...                                                   ...
# 102284  def text(self):\n        """Formatted API decl...
# 102285  def get_type(self, name, api=None):\n        "...
# 102286  def get_features(self, api=None):\n        """...
# 102287  def get_extensions(self, support=None):\n     ...
# 102288  def get_requires(self, api=None, profile=None,...
#
#                                          func_code_tokens  \
# 0       [def, addidsuffix, (, self, ,, idsuffix, ,, re...
# 1       [def, setparents, (, self, ), :, for, c, in, s...
# 2       [def, setdoc, (, self, ,, newdoc, ), :, self, ...
# 3       [def, hastext, (, self, ,, cls, =, 'current', ...
# 4       [def, hasphon, (, self, ,, cls, =, 'current', ...
# ...                                                   ...
# 102284  [def, text, (, self, ), :, out, =, [, ], out, ...
# 102285  [def, get_type, (, self, ,, name, ,, api, =, N...
# 102286  [def, get_features, (, self, ,, api, =, None, ...
# 102287  [def, get_extensions, (, self, ,, support, =, ...
# 102288  [def, get_requires, (, self, ,, api, =, None, ...
#
#                                 func_documentation_string  \
# 0       Appends a suffix to this element's ID, and opt...
# 1       Correct all parent relations for elements with...
# 2       Set a different document. Usually no need to c...
# 3       Does this element have text (of the specified ...
# 4       Does this element have phonetic content (of th...
# ...                                                   ...
# 102284  Formatted API declarations.\n\n        Equival...
# 102285  Returns Type `name`, with preference for the T...
# 102286  Returns filtered list of features in this regi...
# 102287  Returns filtered list of extensions in this re...
# 102288  Returns filtered list of Require objects in th...
#
#                                 func_documentation_tokens split_name  \
# 0       [Appends, a, suffix, to, this, element, s, ID,...      train
# 1       [Correct, all, parent, relations, for, element...      train
# 2       [Set, a, different, document, ., Usually, no, ...      train
# 3       [Does, this, element, have, text, (, of, the, ...      train
# 4       [Does, this, element, have, phonetic, content,...      train
# ...                                                   ...        ...
# 102284                  [Formatted, API, declarations, .]      train
# 102285  [Returns, Type, name, with, preference, for, t...      train
# 102286  [Returns, filtered, list, of, features, in, th...      train
# 102287  [Returns, filtered, list, of, extensions, in, ...      train
# 102288  [Returns, filtered, list, of, Require, objects...      train
#
#                                             func_code_url  func_code_len  \
# 0       https://github.com/proycon/pynlpl/blob/7707f69...             44
# 1       https://github.com/proycon/pynlpl/blob/7707f69...             29
# 2       https://github.com/proycon/pynlpl/blob/7707f69...             53
# 3       https://github.com/proycon/pynlpl/blob/7707f69...            106
# 4       https://github.com/proycon/pynlpl/blob/7707f69...            103
# ...                                                   ...            ...
# 102284  https://github.com/pyokagan/pyglreg/blob/68fa5...             76
# 102285  https://github.com/pyokagan/pyglreg/blob/68fa5...             46
# 102286  https://github.com/pyokagan/pyglreg/blob/68fa5...             35
# 102287  https://github.com/pyokagan/pyglreg/blob/68fa5...             35
# 102288  https://github.com/pyokagan/pyglreg/blob/68fa5...             81
#
#                                                       ast  \
# 0       Module(\n  body=[\n    FunctionDef(\n      nam...
# 1       Module(\n  body=[\n    FunctionDef(\n      nam...
# 2       Module(\n  body=[\n    FunctionDef(\n      nam...
# 3       Module(\n  body=[\n    FunctionDef(\n      nam...
# 4       Module(\n  body=[\n    FunctionDef(\n      nam...
# ...                                                   ...
# 102284  Module(\n  body=[\n    FunctionDef(\n      nam...
# 102285  Module(\n  body=[\n    FunctionDef(\n      nam...
# 102286  Module(\n  body=[\n    FunctionDef(\n      nam...
# 102287  Module(\n  body=[\n    FunctionDef(\n      nam...
# 102288  Module(\n  body=[\n    FunctionDef(\n      nam...
#
#                                                ast_tokens
# 0       [FunctionDef, arguments, arg, arg, arg, Consta...
# 1       [FunctionDef, arguments, arg, Expr, Constant, ...
# 2       [FunctionDef, arguments, arg, arg, Expr, Const...
# 3       [FunctionDef, arguments, arg, arg, arg, arg, C...
# 4       [FunctionDef, arguments, arg, arg, arg, arg, C...
# ...                                                   ...
# 102284  [FunctionDef, arguments, arg, Expr, Constant, ...
# 102285  [FunctionDef, arguments, arg, arg, arg, Consta...
# 102286  [FunctionDef, arguments, arg, arg, Constant, E...
# 102287  [FunctionDef, arguments, arg, arg, Constant, E...
# 102288  [FunctionDef, arguments, arg, arg, arg, arg, C...
#
# [98803 rows x 14 columns]

# %% [markdown]
# ## Convert tokens to sequence of vectors

# %% [markdown]
# Metrics

# %%
mean_func_len = df_train['func_code_tokens'].apply(lambda x : len(x)).mean()
mean_ast_len = df_train['ast_tokens'].apply(lambda x : len(x)).mean()

print(mean_func_len)
print(mean_ast_len)
# Out:
# 96.57097456554963
# 101.22493244132264

# %% [markdown]
# Padding + Truncate + sos + eos

# %%
def preprocess(toks, max_len):
    toks =np.insert(toks, 0, "<sos>")
    
    if len(toks) >= max_len : 
        toks = toks[:max_len-1]
        toks = np.append(toks,"<eos>")
    else:
        toks = np.append(toks,"<eos>")
        while len(toks) < max_len:
            toks = np.append(toks,'<pad>')
    return toks

df_train['processed_func_code_tokens'] = df_train['func_code_tokens'].progress_apply(lambda x: preprocess(x, 200))
df_val['processed_func_code_tokens'] = df_val['func_code_tokens'].progress_apply(lambda x: preprocess(x, 200))
df_test['processed_func_code_tokens'] = df_test['func_code_tokens'].progress_apply(lambda x: preprocess(x, 200))

df_train['processed_ast_code_tokens'] = df_train['ast_tokens'].progress_apply(lambda x: preprocess(x, 200))
df_val['processed_ast_code_tokens'] = df_val['ast_tokens'].progress_apply(lambda x: preprocess(x, 200))
df_test['processed_ast_code_tokens'] = df_test['ast_tokens'].progress_apply(lambda x: preprocess(x, 200))
# Out:
#   0%|          | 0/98803 [00:00<?, ?it/s]
#   0%|          | 0/4880 [00:00<?, ?it/s]
#   0%|          | 0/4983 [00:00<?, ?it/s]
#   0%|          | 0/98803 [00:00<?, ?it/s]
#   0%|          | 0/4880 [00:00<?, ?it/s]
#   0%|          | 0/4983 [00:00<?, ?it/s]

# %% [markdown]
# Training AST vectorization

# %%
# from gensim.models import Word2Vec

# %%
# training_asts = list(df_train['processed_ast_code_tokens'].progress_apply(lambda x: list(x)))
# ast_model = Word2Vec(sentences=training_asts, vector_size=64, window=20, min_count=1, workers=4)
# ast_model.save("ast_word2vec.model")
# Out:
#   0%|          | 0/98803 [00:00<?, ?it/s]

# %%
# training_func_codes = list(df_train['processed_func_code_tokens'].progress_apply(lambda x: list(x)))
# func_model = Word2Vec(sentences=training_func_codes, vector_size=64, window=20, min_count=1, workers=4)
# func_model.save("func_code_word2vec.model")
# Out:
#   0%|          | 0/98803 [00:00<?, ?it/s]

# %% [markdown]
# ## Creating 1-hot Vectors
